# %% [markdown]
# # DATA VISUALIZATION USING MATPLOTLIB

# %%
#EXPERIMENT NO.07

# %%
#Aim: To perform operation on DATA VISUALIZATION USING MATPLOTLIB

# %%
#Name: KHUSHI AJAY MAGARDE
#Roll No: 14
#Class: CSE, 3B
#Subject:ET - 1
#Date: 06.09.2024

# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
x=np.arange(1,12)

# %%
x
# Out:
# array([ 1,  3,  5,  7,  9, 11])

# %%
x= np.arange(1,12,2)

# %%
x
# Out:
# array([ 1,  3,  5,  7,  9, 11])

# %%
y=x*2

# %%
y
# Out:
# array([ 2,  6, 10, 14, 18, 22])

# %% [markdown]
# # LINE CHART

# %%
plt.plot(x,y)
plt.title("Line chart")
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.show()

# %% [markdown]
# # BAR CHART

# %%
plt.bar(x,y)
plt.title("Bar chart")
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.show()

# %% [markdown]
# # SCATTER PLOT

# %%
a=(1,5,2,8,3,6,9,4,8)
b=(10,20,54,20,54,33,84,44,15)

plt.scatter(a,b)
plt.title("scatter plot")
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.show()

# %%
plt.scatter(x,y)
plt.title("scatter plot")
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.show()

# %% [markdown]
# # HISTOGRAM

# %%
H=[1,1,2,2,2,2,4,4,4,4,8,8,8,6,6,2,2,7,3,1,9,5,5,5,5,8,2,2,2,2,1,1,4,4,4,4,4]

# %%
plt.hist(H)
plt.show()

# %% [markdown]
# # PIE CHART

# %%
import matplotlib.pyplot as plt

# Data to plot
labels = ['A', 'B', 'C', 'D']
sizes = [25, 35, 20, 20]  # Percentages for each category
colors = ['gold', 'lightcoral', 'lightskyblue', 'yellowgreen']  # Optional colors for each section

# Creating the pie chart
plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%',shadow=True, startangle=140)

# Equal aspect ratio ensures that pie chart is drawn as a circle.
plt.axis('equal')

# Show the pie chart
plt.title('PIE CHART EXAMPLE')
plt.show()
